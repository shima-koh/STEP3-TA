# %% [markdown]
# # STEP3 TA IndéMode  データ取得 近隣サロン

# %% [markdown]
# >### 環境構築

# %% [markdown]
# ターミナルにて
#  ● pip install requests
#  ● pip install beautifulsoup4
#  ● pip install gspread
#  ● pip install google-auth

# %% [markdown]
# >### 活用サイト

# %% [markdown]
# 楽天Beauty
# https://beauty.rakuten.co.jp/

# %% [markdown]
# 規約確認
# ✔ https://beauty.rakuten.co.jp/robots.txt
# 　→「Disallow:/rent_store 」を検索 → 無し
# ✔ プライバシーポリシー
# 　→スクレイピング・クローリング禁止の記載なし

# %% [markdown]
# >### コード

# %%
# ライブラリインポート
from time import sleep
import requests
from bs4 import BeautifulSoup
import pandas as pd
import gspread 
from google.oauth2 import service_account
import json

# スプレッドシートの認証設定
SP_CREDENTIAL_FILE = 'gspread-test-399313-ca3a69c4d75e.json' #個人の認証キーのjsonファイルのパスを記入
SP_COPE = [
    'https://www.googleapis.com/auth/drive',
    'https://spreadsheets.google.com/feeds'
]
credentials = service_account.Credentials.from_service_account_file(SP_CREDENTIAL_FILE, scopes=SP_COPE)
gc = gspread.authorize(credentials)

#スプレッドシート/シート指定
SP_SHEET_KEY = '1474-fT6RkuGOvPwjyCJIEtD6qrNjI6EP2bw3vtHvLBc' #川名のスプレッドシート
SP_SHEET = '最寄駅近隣サロンDB'

# 情報格納のための空配列を用意
s_name = []
s_access = []
s_price = []


# HTML取得
URL = 'https://beauty.rakuten.co.jp/eki571/page{}/'

# 複数ページ取得のためのループ処理
for i in range(1,6):

    # 変数trget_urlに、アクセス先のURLを格納する
    target_url = URL.format(i)

    #サーバー負荷低減のための1s待機
    sleep(1)

    #print()してtrget_url確認
    print(target_url)

    # リクエスト
    res = requests.get(target_url)

    # リクエスト結果を確認
    #result = res.text
    #print(result)

    # 文字コード変換 (→ utf-8 )
    res.encoding = 'utf-8'

    # 文字化けしていないかhtmlを確認
    #print(res.text)

    # BeautifulSoup(解析したいデータ,解析する方法)を指定し、soupに代入
    soup = BeautifulSoup(res.text, "html.parser")
    #print(soup)

    # sectionデータ(1物件分データ)の取得
    property_section = soup.select('div.m-shopCard__headerContent')

    # 取得したセクションすべての数を確認します。
    print(len(property_section))

    # property_sectionからsectionを1つずつ取り出してpsに代入。
    for ps in property_section:
        ps1 = ps.select('h3.m-shopCard__shopName')[0].text
        ps2 = ps.select('li.m-shopCard__headerOutlineItem')[0].text.replace("アクセス：","")
        ps3 = ps.select('li.m-shopCard__headerOutlineItem')[1].text.replace("カット単価：","").replace("～","").replace("￥","")

        # それぞれ抽出したデータを配列に追加
        s_name.append(ps1)
        s_access.append(ps2)
        s_price.append(ps3)
        
    # 物件数確認
    #print('サロン件数', len(s_name))

# データ定義
data_list = {
    "サロン名" : s_name,
    "アクセス" : s_access,
    "カット単価(円~)" : s_price,
}

# データフレーム作成
df = pd.DataFrame(data_list)

# 重複データ処理
df.drop_duplicates(inplace=True)
df.reset_index(drop=True,inplace=True)
#display(df)

# csv保存
#df.to_csv('東京都新宿区の貸店舗・テナント物件一覧_店舗ネットワーク.csv', index=False)

# スプレッドシート/シートを選択して初期化既存データ削除）
sh = gc.open_by_key(SP_SHEET_KEY)
worksheet = sh.worksheet(SP_SHEET)
worksheet.clear() 

# DataFrameをシートに書き込む
#worksheet.update([filtered_df.columns.values.tolist()] + filtered_df.values.tolist())
worksheet.update(values=[df.columns.values.tolist()] + df.values.tolist(), range_name='A1')

print('スプレッドシートへの書き込みが完了しました')
# Out:
# https://beauty.rakuten.co.jp/eki571/page1/
# 30
# https://beauty.rakuten.co.jp/eki571/page2/
# 30
# https://beauty.rakuten.co.jp/eki571/page3/
# 30
# https://beauty.rakuten.co.jp/eki571/page4/
# 21
# https://beauty.rakuten.co.jp/eki571/page5/
# 0
# スプレッドシートへの書き込みが完了しました

# %%
ps = property_section[0]
ps1 = ps.select('h3.m-shopCard__shopName')[0].text
print(ps1)
ps2 = ps.select('li.m-shopCard__headerOutlineItem')[0].text
print(ps2)
ps3 = ps.select('li.m-shopCard__headerOutlineItem')[1].text
ps3
# Out:
# Euphoria GINZA GRANDE 銀座(ユーフォリア　ギンザ　グランデ)
# アクセス：銀座駅 徒歩1分
# 、有楽町駅 徒歩5分
# 'カット単価：￥5,500～'

# %%
# データ確認
filtered_df
# Out:
#                          物件名     使用階/部屋番号                 所在地
# 0                  ローカルステイ中井       1/1階部分   東京都新宿区上落合２丁目19-13  \
# 1         ＲＥＳＴＡ　ＴＡＫＡＤＡＮＯＢＡＢＡ            -       東京都新宿区高田馬場3-2
# 2            高田馬場　第９０東京ビル　３階            3     東京都新宿区高田馬場3-5-3
# 3                   西早稲田１階店舗            1   東京都新宿区西早稲田1-23-13
# 4                   ＫＭプラザ　３Ｆ    3/302-303   東京都新宿区大久保１丁目16-27
# 5                       小玉ビル        4/403   東京都新宿区西新宿7丁目19-11
# 6                   ＭＡフラットビル            1    東京都新宿区高田馬場2-7-13
# 7               第二サンパークビル　１階            1      東京都新宿区新宿3-21-4
# 8                      四谷林ビル     1棟/1階~3階    東京都新宿区四谷一丁目18-11
# 9               恩田セントラルビル　４階        4/401       東京都新宿区新宿3-3-3
# 10                   ｒａｕｍ神楽坂            1     東京都新宿区東五軒町4番14号
# 11                  三宅ビル　Ｂ１階           B1      東京都新宿区四谷1丁目9番地
# 12                   三宅ビル　２階            2      東京都新宿区四谷1丁目9番地
# 13              新宿第五葉山ビル　Ｂ１階           B1      東京都新宿区新宿5-11-1
# 14               新宿１丁目南ビル　１階            1       東京都新宿区新宿1-6-3
# 15          サンパークＡＮＮＥＸビル　Ｂ１階           B1      東京都新宿区新宿3-22-2
# 16                    灯ビル　３階            3   東京都新宿区歌舞伎町１丁目26-6
# 17              ソレイユヤマカワ　１階　            1     東京都新宿区上落合1-27-8
# 18           メトロシティ西早稲田ビル　３階            3     東京都新宿区高田馬場1-1-1
# 19                      大安ビル            6      東京都新宿区新宿3-36-6
# 20                 西口三平ビル　２階            2     東京都新宿区西新宿1-12-5
# 21             ニューサンパークビル　４階            4      東京都新宿区新宿3-20-5
# 22        ニューサンパークビル　Ｂ１階～Ｂ２階       B1~B2階      東京都新宿区新宿3-20-5
# 23           ニューサンパークビル別館　１棟           1棟      東京都新宿区新宿3-20-3
# 6        ＪＲ山手線 高田馬場   48.00    26.18     261     57
# 7          ＪＲ山手線 新宿   59.10    181.5    1815    181
# 8     東京メトロ丸ノ内線 四ツ谷  256.15    132.0     792      0
# 9   東京メトロ副都心線 新宿三丁目   62.35    62.24     622     68
# 10     東京メトロ東西線 神楽坂    6.21     4.62       0      5
# 11  東京メトロ丸ノ内線 四谷三丁目  110.75    63.74     637     70
# 12  東京メトロ丸ノ内線 四谷三丁目   99.34    66.11     661     72
# 13  東京メトロ丸ノ内線 新宿三丁目   99.17    44.55     311     44
# 14  東京メトロ丸ノ内線 新宿御苑前  100.00    99.83       0      0
# 15         ＪＲ山手線 新宿  125.10    154.0    1540    169
# 16     西武鉄道新宿線 西武新宿  201.14   147.24    1472      0
# 17      東京メトロ東西線 落合   96.70     40.7       0     44
# 18   東京メトロ副都心線 西早稲田  124.77    75.48       0     83
# 19         ＪＲ山手線 新宿  254.84    212.0    2544      0
# 20         ＪＲ山手線 新宿  325.85    385.0    3850    423
# 21         ＪＲ山手線 新宿  227.97    231.0    2310    254
# 22         ＪＲ山手線 新宿  308.30    385.0    3850    423
# 23         ＪＲ山手線 新宿  380.01    385.0    3850    423
# 24       西武鉄道新宿線 中井   24.88     22.0     132     24
# 25  東京メトロ副都心線 新宿三丁目   61.13     95.6     956    105
# 26       都営大江戸線 都庁前   82.55      0.0       0      0
# 27     西武鉄道新宿線 西武新宿  120.16    65.78     526      0
# 28     東京メトロ東西線 神楽坂  189.36  182.424       0    182
# 29     東京メトロ南北線 四ツ谷   51.37     34.1     341      0
# 30   東京メトロ有楽町線 江戸川橋   54.86     30.0     180     60
# 31       京王電鉄京王線 初台   30.48     9.57      28      9
# 32       ＪＲ山手線 高田馬場   48.26     18.7      93     18
# 33        都電荒川線 早稲田   60.74     30.0       0     30
# 34     東京メトロ東西線 早稲田   81.54    40.68     406     40
# 35      都営大江戸線 新宿西口   55.75    37.53     225      0
# 36    都営大江戸線 西新宿五丁目   81.97    40.48     161     40
# 37     都営大江戸線 牛込神楽坂   90.38     64.9       0     64
# 38        ＪＲ総武線 信濃町   31.10    16.75     167      0
# 39  東京メトロ丸ノ内線 四谷三丁目   40.00     33.0     198     33
# 40      都営大江戸線 牛込柳町   54.46     39.6       0      0
# 41         ＪＲ山手線 新宿   78.65    75.89     607     75
# 42       都営大江戸線 東新宿   90.64     71.3       0      0
# 43       都営大江戸線 東新宿   90.64     71.3       0      0
# 44       都営大江戸線 東新宿   90.64     71.3       0      0
# 45         都営新宿線 曙橋  115.52  69.1812     415     69
# 46    東京メトロ副都心線 東新宿   45.45     25.0      50     25
# 47       ＪＲ山手線 高田馬場   44.00    17.27       0      0
# 48     西武鉄道新宿線 西武新宿   84.48    40.96     122     40
# 49    東京メトロ丸ノ内線 西新宿   27.68     16.5      49     16
# 50   東京メトロ有楽町線 江戸川橋   31.36    15.95       0      0
# 51         ＪＲ山手線 新宿   19.39     14.0       0     14
# 52        ＪＲ総武線 大久保   27.66     27.0     135     27
# 53         ＪＲ山手線 新宿   66.00     26.4       0     26
# 54      都営大江戸線 新宿西口   17.04     12.1      36     12
