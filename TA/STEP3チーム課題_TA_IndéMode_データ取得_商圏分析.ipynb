# %% [markdown]
# # STEP3 TA IndéMode  データ取得 周辺人口

# %% [markdown]
# >### 環境構築

# %% [markdown]
# ターミナルにて
#  ● pip install requests
#  ● pip install urllib3
#  ● pip install beautifulsoup4
#  ● pip install gspread
#  ● pip install google-auth

# %% [markdown]
# >### 活用API

# %% [markdown]
# ●　国土地理院API : 住所を緯度経度に変換
# ●　jSTAT MAP API ：商圏分析

# %% [markdown]
# >### コード

# %%
# ライブラリインポート
import requests
import urllib.request
import pandas as pd
import gspread 
from google.oauth2 import service_account
import json
import sqlite3

# 国土地理院APIから緯度経度を取得
Address = "東京都千代田区有楽町2-2-13"
makeUrl = "https://msearch.gsi.go.jp/address-search/AddressSearch?q="
s_quote = urllib.parse.quote(Address)
response = requests.get(makeUrl + s_quote)

#緯度を表示
#print(response.json()[0]["geometry"]["coordinates"][0])
#経度を表示
#print(response.json()[0]["geometry"]["coordinates"][1])

#jSTAT MAP認証設定
REQUEST_URL = 'https://jstatmap.e-stat.go.jp/statmap/api/1.00?category=richReport&func=getSummary'
USER_ID = '&userid=noriyasukawana@outlook.jp'  #個人の登録ID
API_KEY = '&key=dMUbbbyc9ThTzG4PNpA2'  #個人のAPIキー

# params入力設定
latitude = '&lat=' + str(response.json()[0]["geometry"]["coordinates"][1])  # 緯度
longitude = '&lng=' + str(response.json()[0]["geometry"]["coordinates"][0])  # 経度
rangeType = '&rangeType=driveTime'  # circle(円) or driveTime(到達圏)
travelMode = '&travelMode=walking'  # car(車) or walking(徒歩)
speed = '&speed=3.2'  # 時速(km/h)
time = '&time=15,30,45'  # 移動時間(min)
output = '&output=json'  # 出力形式
radius = '&radius=500'

# リクエスト
res = requests.get(REQUEST_URL + USER_ID + latitude + longitude + rangeType + travelMode + speed + time + API_KEY + output)
result = res.json()

#性別別人口
Gender_pop = result['GET_SUMMARY']['DATASET_INF'][0]['TABLE_INF'][0]['DATA_INF']['VALUE']
Gender_pop2 = [{key: value for key, value in entry.items() if key not in ['@cat11', '@cat12']} for entry in Gender_pop]
Gender_pop3 = [entry['$'] for entry in Gender_pop2]
# リストを3つずつに分割
list_Gender = [Gender_pop3[i:i+3] for i in range(0, len(Gender_pop3), 3)]
# DataFrameに変換
df_Gender = pd.DataFrame(list_Gender, columns=['総人口', '男性人口', '女性人口'])
#display(df_Gender)

#年齢別人口
Age_pop = result['GET_SUMMARY']['DATASET_INF'][0]['TABLE_INF'][1]['DATA_INF']['VALUE']
Age_pop2 = [{key: value for key, value in entry.items() if key not in ['@cat11', '@cat13']} for entry in Age_pop]
Age_pop3 = [entry['$'] for entry in Age_pop2]
# リストを3つずつに分割
list_Age = [Age_pop3[i:i+16] for i in range(0, len(Age_pop3), 16)]
# DataFrameに変換
df_Age = pd.DataFrame(list_Age, columns=['4 歳以下', '5～9 歳', '10～14 歳', '15～19 歳', '20～24 歳', '25～29 歳', '30～34 歳','35～39 歳', '40～44 歳','45～49 歳', '50～54 歳','55～59 歳', '60～64 歳','65～69 歳', '70～74 歳','75 歳以上'])
#display(df_Age)

# DataFrameを結合
df = pd.concat([df_Gender, df_Age], axis=1)
#display(df)

# 項目作成
class_name = result['GET_SUMMARY']['DATASET_INF'][0]['TABLE_INF'][0]['CLASS_INF']['CLASS_OBJ'][0]['CLASS']
class_name2 = [{key: value for key, value in entry.items() if key not in ['@code']} for entry in class_name]
class_name3 = [entry['@name'] for entry in class_name2]

# 項目カラムを用意
item_column = ['徒歩15分圏内', '徒歩30分圏内', '徒歩45分圏内', class_name3[3], class_name3[4]]

# 項目カラムをDataFrameの先頭列に追加
df.insert(0, '項目', item_column)
#display(df)


# スプレッドシートにデータ保存
# スプレッドシートの認証設定
SP_CREDENTIAL_FILE = 'gspread-test-399313-ca3a69c4d75e.json' #個人の認証キーのjsonファイルのパスを記入
SP_COPE = [
    'https://www.googleapis.com/auth/drive',
    'https://spreadsheets.google.com/feeds'
]
credentials = service_account.Credentials.from_service_account_file(SP_CREDENTIAL_FILE, scopes=SP_COPE)
gc = gspread.authorize(credentials)

#スプレッドシート/シート指定
SP_SHEET_KEY = '1474-fT6RkuGOvPwjyCJIEtD6qrNjI6EP2bw3vtHvLBc' #川名のスプレッドシート
SP_SHEET = '周辺人口DB'
# スプレッドシート/シートを選択して初期化既存データ削除）
sh = gc.open_by_key(SP_SHEET_KEY)
worksheet = sh.worksheet(SP_SHEET)
worksheet.clear() 

# DataFrameをシートに書き込む
worksheet.update(values=[df.columns.values.tolist()] + df.values.tolist(), range_name='A1')

print('スプレッドシートへの書き込みが完了しました')
# Out:
# c:\Users\noriyasukawana\AppData\Local\Programs\Python\Python311\Lib\site-packages\gspread\worksheet.py:1069: UserWarning: [Deprecated][in version 6.0.0]: method signature will change to: 'Worksheet.update(value = [[]], range_name=)' arguments 'range_name' and 'values' will swap, values will be mandatory of type: 'list(list(...))'
#   warnings.warn(
# スプレッドシートへの書き込みが完了しました

# %%
# SQLでDBにデータ保存
# SQLiteデータベースへの接続
db_path = "STEP3チーム課題_TA_IndéMode_DB.db"
conn = sqlite3.connect(db_path) 

# データフレームをSQLiteデータベースに書き込む
table_name = '商圏人口構成'  # テーブル名を適切なものに変更してください
df.to_sql(table_name, conn, if_exists='replace', index=False)

print(db_path + ' への書き込みが完了しました')
# Out:
# STEP3チーム課題_TA_IndéMode_DB.db への書き込みが完了しました

# %% [markdown]
# >### 雑コード

# %%
import sqlite3

# %%
# SQLiteデータベースへの接続
db_path = "STEP3チーム課題_TA_IndéMode_DB.db"
conn = sqlite3.connect(db_path) 

# データフレームをSQLiteデータベースに書き込む
table_name = '商圏人口構成'  # テーブル名を適切なものに変更してください
df.to_sql(table_name, conn, if_exists='replace', index=False)
# Out:
# 5

# %%
# sample_data.db がなかったら作成、あったら接続
# db_path = "STEP3チーム課題_TA_IndéMode_DB.db"
# conn = sqlite3.connect(db_path)

# テーブル作成関数
#def create_table():
#    sql = '''CREATE TABLE IF NOT EXISTS SAMPLE
#                 (ID    INTEGER PRIMARY KEY,
#                  TEST1 TEXT,
#                  TEST2 TEXT,
#                  TEST3 TEXT)'''

#    conn.execute(sql)
#    conn.commit()
#    conn.close()

# データ挿入関数
#def insert_record():
#    sql = "INSERT INTO SAMPLE VALUES (1, 'あ', 'い', 'う')"
#    conn.execute(sql)

#    sql = "INSERT INTO SAMPLE VALUES (2, 'てすと１', 'てすと２', 'てすと３')"
#    conn.execute(sql)

#    sql = "INSERT INTO SAMPLE VALUES (3, '12345', '22222', '55555')"
#    conn.execute(sql)

#    conn.commit()
#    conn.close()

# データ更新関数
#def update_record():
#    sql = "UPDATE SAMPLE SET TEST1 = 'か' WHERE ID = 1"
#    conn.execute(sql)
#    conn.commit()
#    conn.close()

# データ削除関数
#def delete_record():
#    sql = "DELETE FROM SAMPLE WHERE ID = 3"
#    conn.execute(sql)
#    conn.commit()
#    conn.close()

# データ検索関数
#def select_record():
#    sql = "SELECT * FROM SAMPLE WHERE ID = 2"
#    for row in conn.execute(sql):
#        print(row)

# 関数実行
#create_table()
#insert_record()

# %%
# ライブラリインポート
import requests
import urllib.request
import pandas as pd

# %%
# 国土地理院APIから緯度経度を取得
Address = "千葉市稲毛区轟町３丁目"
makeUrl = "https://msearch.gsi.go.jp/address-search/AddressSearch?q="
s_quote = urllib.parse.quote(Address)
response = requests.get(makeUrl + s_quote)

#緯度を表示
print(response.json()[0]["geometry"]["coordinates"][0])
#経度を表示
print(response.json()[0]["geometry"]["coordinates"][1])
# Out:
# 140.109146
# 35.62973

# %%
#jSTAT MAP認証設定
REQUEST_URL = 'https://jstatmap.e-stat.go.jp/statmap/api/1.00?category=richReport&func=getSummary'
USER_ID = '&userid=noriyasukawana@outlook.jp'  #個人の登録ID
API_KEY = '&key=dMUbbbyc9ThTzG4PNpA2'  #個人のAPIキー

# params入力設定
latitude = '&lat=' + str(response.json()[0]["geometry"]["coordinates"][1])  # 緯度
longitude = '&lng=' + str(response.json()[0]["geometry"]["coordinates"][0])  # 経度
rangeType = '&rangeType=driveTime'  # circle(円) or driveTime(到達圏)
travelMode = '&travelMode=walking'  # car(車) or walking(徒歩)
speed = '&speed=3.2'  # 時速(km/h)
time = '&time=15,30,45'  # 移動時間(min)
output = '&output=json'  # 出力形式
radius = '&radius=500'

# %%
# リクエスト
res = requests.get(REQUEST_URL + USER_ID + latitude + longitude + rangeType + travelMode + speed + time + API_KEY + output)
result = res.json()

# %%
result
# Out:
# {'GET_SUMMARY': {'RESULT': {'STATUS': 0,
#    'ERROR_MSG': '正常終了しました。',
#    'DATE': '2023-09-19 18:31:57'},
#   'PARAMETER': {'LATITUDE': 35.62973,
#    'LONGITUDE': 140.109146,
#    'RANGE_TYPE': 'driveTime',
#    'TRAVEL_MODE': 'walking',
#    'SPEED': 3,
#    'TIME': [{'@level': 3, '@unit': '分', '$': 40}]},
#   'POSITION_INF': {'PREFECTURE': '千葉県', 'CITY': '千葉市稲毛区', 'BLOCK': '轟町三丁目'},
#   'DATASET_INF': [{'TABLE_INF': [{'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '人口',
#       'TITLE': 'TABLE01 男女別人口',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat11',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat12',
#          '@name': '男女',
#          'CLASS': [{'@code': '1200', '@name': '男女計'},
#           {'@code': '1201', '@name': '男'},
#           {'@code': '1202', '@name': '女'}]}]},
#       'DATA_INF': {'VALUE': [{'@cat11': 'R001',
#          '@cat12': '1200',
#          '@unit': '人',
#          '$': '3151'},
#         {'@cat11': 'R001', '@cat12': '1201', '@unit': '人', '$': '1588'},
#         {'@cat11': 'R001', '@cat12': '1202', '@unit': '人', '$': '1563'},
#         {'@cat11': 'R002', '@cat12': '1200', '@unit': '人', '$': '15776'},
#         {'@cat11': 'R002', '@cat12': '1201', '@unit': '人', '$': '8034'},
#         {'@cat11': 'R002', '@cat12': '1202', '@unit': '人', '$': '7742'},
#         {'@cat11': 'R003', '@cat12': '1200', '@unit': '人', '$': '73461'},
#         {'@cat11': 'R003', '@cat12': '1201', '@unit': '人', '$': '36662'},
#         {'@cat11': 'R003', '@cat12': '1202', '@unit': '人', '$': '36799'},
#         {'@cat11': 'R010', '@cat12': '1200', '@unit': '人', '$': '160582'},
#         {'@cat11': 'R010', '@cat12': '1201', '@unit': '人', '$': '80345'},
#         {'@cat11': 'R010', '@cat12': '1202', '@unit': '人', '$': '80237'},
#         {'@cat11': 'R100', '@cat12': '1200', '@unit': '人', '$': '6284480'},
#         {'@cat11': 'R100', '@cat12': '1201', '@unit': '人', '$': '3117987'},
#         {'@cat11': 'R100', '@cat12': '1202', '@unit': '人', '$': '3166493'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '人口',
#       'TITLE': 'TABLE02 年齢（5歳階級）別人口',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat11',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat13',
#          '@name': '年齢（5歳階級）',
#          'CLASS': [{'@code': '1301', '@name': '4歳以下', '@unit': '人'},
#           {'@code': '1302', '@name': '5～9歳', '@unit': '人'},
#           {'@code': '1303', '@name': '10～14歳', '@unit': '人'},
#           {'@code': '1304', '@name': '15～19歳', '@unit': '人'},
#           {'@code': '1305', '@name': '20～24歳', '@unit': '人'},
#           {'@code': '1306', '@name': '25～29歳', '@unit': '人'},
#           {'@code': '1307', '@name': '30～34歳', '@unit': '人'},
#           {'@code': '1308', '@name': '35～39歳', '@unit': '人'},
#           {'@code': '1309', '@name': '40～44歳', '@unit': '人'},
#           {'@code': '1310', '@name': '45～49歳', '@unit': '人'},
#           {'@code': '1311', '@name': '50～54歳', '@unit': '人'},
#           {'@code': '1312', '@name': '55～59歳', '@unit': '人'},
#           {'@code': '1313', '@name': '60～64歳', '@unit': '人'},
#           {'@code': '1314', '@name': '65～69歳', '@unit': '人'},
#           {'@code': '1315', '@name': '70～74歳', '@unit': '人'},
#           {'@code': '1316', '@name': '75歳以上', '@unit': '人'}]}]},
#       'DATA_INF': {'VALUE': [{'@cat11': 'R001',
#          '@cat13': '1301',
#          '@unit': '人',
#          '$': '109'},
#         {'@cat11': 'R001', '@cat13': '1302', '@unit': '人', '$': '138'},
#         {'@cat11': 'R001', '@cat13': '1303', '@unit': '人', '$': '159'},
#         {'@cat11': 'R001', '@cat13': '1304', '@unit': '人', '$': '192'},
#         {'@cat11': 'R001', '@cat13': '1305', '@unit': '人', '$': '252'},
#         {'@cat11': 'R001', '@cat13': '1306', '@unit': '人', '$': '158'},
#         {'@cat11': 'R001', '@cat13': '1307', '@unit': '人', '$': '127'},
#         {'@cat11': 'R001', '@cat13': '1308', '@unit': '人', '$': '161'},
#         {'@cat11': 'R001', '@cat13': '1309', '@unit': '人', '$': '181'},
#         {'@cat11': 'R001', '@cat13': '1310', '@unit': '人', '$': '278'},
#         {'@cat11': 'R001', '@cat13': '1311', '@unit': '人', '$': '206'},
#         {'@cat11': 'R001', '@cat13': '1312', '@unit': '人', '$': '213'},
#         {'@cat11': 'R001', '@cat13': '1313', '@unit': '人', '$': '181'},
#         {'@cat11': 'R001', '@cat13': '1314', '@unit': '人', '$': '143'},
#         {'@cat11': 'R001', '@cat13': '1315', '@unit': '人', '$': '157'},
#         {'@cat11': 'R001', '@cat13': '1316', '@unit': '人', '$': '269'},
#         {'@cat11': 'R002', '@cat13': '1301', '@unit': '人', '$': '460'},
#         {'@cat11': 'R002', '@cat13': '1302', '@unit': '人', '$': '571'},
#         {'@cat11': 'R002', '@cat13': '1303', '@unit': '人', '$': '636'},
#         {'@cat11': 'R002', '@cat13': '1304', '@unit': '人', '$': '831'},
#         {'@cat11': 'R002', '@cat13': '1305', '@unit': '人', '$': '1298'},
#         {'@cat11': 'R002', '@cat13': '1306', '@unit': '人', '$': '680'},
#         {'@cat11': 'R002', '@cat13': '1307', '@unit': '人', '$': '653'},
#         {'@cat11': 'R002', '@cat13': '1308', '@unit': '人', '$': '766'},
#         {'@cat11': 'R002', '@cat13': '1309', '@unit': '人', '$': '890'},
#         {'@cat11': 'R002', '@cat13': '1310', '@unit': '人', '$': '1102'},
#         {'@cat11': 'R002', '@cat13': '1311', '@unit': '人', '$': '961'},
#         {'@cat11': 'R002', '@cat13': '1312', '@unit': '人', '$': '942'},
#         {'@cat11': 'R002', '@cat13': '1313', '@unit': '人', '$': '814'},
#         {'@cat11': 'R002', '@cat13': '1314', '@unit': '人', '$': '890'},
#         {'@cat11': 'R002', '@cat13': '1315', '@unit': '人', '$': '966'},
#         {'@cat11': 'R002', '@cat13': '1316', '@unit': '人', '$': '1822'},
#         {'@cat11': 'R003', '@cat13': '1301', '@unit': '人', '$': '2112'},
#         {'@cat11': 'R003', '@cat13': '1302', '@unit': '人', '$': '2637'},
#         {'@cat11': 'R003', '@cat13': '1303', '@unit': '人', '$': '2910'},
#         {'@cat11': 'R003', '@cat13': '1304', '@unit': '人', '$': '3408'},
#         {'@cat11': 'R003', '@cat13': '1305', '@unit': '人', '$': '5173'},
#         {'@cat11': 'R003', '@cat13': '1306', '@unit': '人', '$': '3278'},
#         {'@cat11': 'R003', '@cat13': '1307', '@unit': '人', '$': '3186'},
#         {'@cat11': 'R003', '@cat13': '1308', '@unit': '人', '$': '3720'},
#         {'@cat11': 'R003', '@cat13': '1309', '@unit': '人', '$': '4420'},
#         {'@cat11': 'R003', '@cat13': '1310', '@unit': '人', '$': '5268'},
#         {'@cat11': 'R003', '@cat13': '1311', '@unit': '人', '$': '4714'},
#         {'@cat11': 'R003', '@cat13': '1312', '@unit': '人', '$': '4012'},
#         {'@cat11': 'R003', '@cat13': '1313', '@unit': '人', '$': '3589'},
#         {'@cat11': 'R003', '@cat13': '1314', '@unit': '人', '$': '3750'},
#         {'@cat11': 'R003', '@cat13': '1315', '@unit': '人', '$': '4350'},
#         {'@cat11': 'R003', '@cat13': '1316', '@unit': '人', '$': '8786'},
#         {'@cat11': 'R010', '@cat13': '1301', '@unit': '人', '$': '5273'},
#         {'@cat11': 'R010', '@cat13': '1302', '@unit': '人', '$': '6328'},
#         {'@cat11': 'R010', '@cat13': '1303', '@unit': '人', '$': '6977'},
#         {'@cat11': 'R010', '@cat13': '1304', '@unit': '人', '$': '7671'},
#         {'@cat11': 'R010', '@cat13': '1305', '@unit': '人', '$': '8592'},
#         {'@cat11': 'R010', '@cat13': '1306', '@unit': '人', '$': '7035'},
#         {'@cat11': 'R010', '@cat13': '1307', '@unit': '人', '$': '7416'},
#         {'@cat11': 'R010', '@cat13': '1308', '@unit': '人', '$': '8947'},
#         {'@cat11': 'R010', '@cat13': '1309', '@unit': '人', '$': '10536'},
#         {'@cat11': 'R010', '@cat13': '1310', '@unit': '人', '$': '12996'},
#         {'@cat11': 'R010', '@cat13': '1311', '@unit': '人', '$': '11391'},
#         {'@cat11': 'R010', '@cat13': '1312', '@unit': '人', '$': '9375'},
#         {'@cat11': 'R010', '@cat13': '1313', '@unit': '人', '$': '8330'},
#         {'@cat11': 'R010', '@cat13': '1314', '@unit': '人', '$': '9234'},
#         {'@cat11': 'R010', '@cat13': '1315', '@unit': '人', '$': '11050'},
#         {'@cat11': 'R010', '@cat13': '1316', '@unit': '人', '$': '21491'},
#         {'@cat11': 'R100', '@cat13': '1301', '@unit': '人', '$': '221053'},
#         {'@cat11': 'R100', '@cat13': '1302', '@unit': '人', '$': '248798'},
#         {'@cat11': 'R100', '@cat13': '1303', '@unit': '人', '$': '264645'},
#         {'@cat11': 'R100', '@cat13': '1304', '@unit': '人', '$': '281545'},
#         {'@cat11': 'R100', '@cat13': '1305', '@unit': '人', '$': '316219'},
#         {'@cat11': 'R100', '@cat13': '1306', '@unit': '人', '$': '311470'},
#         {'@cat11': 'R100', '@cat13': '1307', '@unit': '人', '$': '329858'},
#         {'@cat11': 'R100', '@cat13': '1308', '@unit': '人', '$': '372869'},
#         {'@cat11': 'R100', '@cat13': '1309', '@unit': '人', '$': '423399'},
#         {'@cat11': 'R100', '@cat13': '1310', '@unit': '人', '$': '507856'},
#         {'@cat11': 'R100', '@cat13': '1311', '@unit': '人', '$': '447662'},
#         {'@cat11': 'R100', '@cat13': '1312', '@unit': '人', '$': '382032'},
#         {'@cat11': 'R100', '@cat13': '1313', '@unit': '人', '$': '342781'},
#         {'@cat11': 'R100', '@cat13': '1314', '@unit': '人', '$': '387685'},
#         {'@cat11': 'R100', '@cat13': '1315', '@unit': '人', '$': '452539'},
#         {'@cat11': 'R100', '@cat13': '1316', '@unit': '人', '$': '859767'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '人口',
#       'TITLE': 'TABLE03 年齢階級別人口',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat11',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat14',
#          '@name': '年齢階級',
#          'CLASS': [{'@code': '1401', '@name': '年少人口（ 0歳～14歳）', '@unit': '人'},
#           {'@code': '1402', '@name': '生産年齢人口（15歳～64歳）', '@unit': '人'},
#           {'@code': '1403', '@name': '老年人口（65歳以上）', '@unit': '人'},
#           {'@code': '1404', '@name': '15歳以上就業者数', '@unit': '人'},
#           {'@code': '1405', '@name': '後期高齢者数（75歳以上）', '@unit': '人'}]}]},
#       'DATA_INF': {'VALUE': [{'@cat11': 'R001',
#          '@cat14': '1401',
#          '@unit': '人',
#          '$': '405'},
#         {'@cat11': 'R001', '@cat14': '1402', '@unit': '人', '$': '1951'},
#         {'@cat11': 'R001', '@cat14': '1403', '@unit': '人', '$': '568'},
#         {'@cat11': 'R001', '@cat14': '1404', '@unit': '人', '$': '1392'},
#         {'@cat11': 'R001', '@cat14': '1405', '@unit': '人', '$': '269'},
#         {'@cat11': 'R002', '@cat14': '1401', '@unit': '人', '$': '1667'},
#         {'@cat11': 'R002', '@cat14': '1402', '@unit': '人', '$': '8937'},
#         {'@cat11': 'R002', '@cat14': '1403', '@unit': '人', '$': '3678'},
#         {'@cat11': 'R002', '@cat14': '1404', '@unit': '人', '$': '6757'},
#         {'@cat11': 'R002', '@cat14': '1405', '@unit': '人', '$': '1822'},
#         {'@cat11': 'R003', '@cat14': '1401', '@unit': '人', '$': '7658'},
#         {'@cat11': 'R003', '@cat14': '1402', '@unit': '人', '$': '40768'},
#         {'@cat11': 'R003', '@cat14': '1403', '@unit': '人', '$': '16886'},
#         {'@cat11': 'R003', '@cat14': '1404', '@unit': '人', '$': '31669'},
#         {'@cat11': 'R003', '@cat14': '1405', '@unit': '人', '$': '8786'},
#         {'@cat11': 'R010', '@cat14': '1401', '@unit': '人', '$': '18578'},
#         {'@cat11': 'R010', '@cat14': '1402', '@unit': '人', '$': '92289'},
#         {'@cat11': 'R010', '@cat14': '1403', '@unit': '人', '$': '41775'},
#         {'@cat11': 'R010', '@cat14': '1404', '@unit': '人', '$': '69177'},
#         {'@cat11': 'R010', '@cat14': '1405', '@unit': '人', '$': '21491'},
#         {'@cat11': 'R100', '@cat14': '1401', '@unit': '人', '$': '734496'},
#         {'@cat11': 'R100', '@cat14': '1402', '@unit': '人', '$': '3715691'},
#         {'@cat11': 'R100', '@cat14': '1403', '@unit': '人', '$': '1699991'},
#         {'@cat11': 'R100', '@cat14': '1404', '@unit': '人', '$': '2862135'},
#         {'@cat11': 'R100', '@cat14': '1405', '@unit': '人', '$': '859767'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '世帯',
#       'TITLE': 'TABLE04 世帯人員別世帯数Ａ',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat11',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat15',
#          '@name': '世帯人員Ａ',
#          'CLASS': [{'@code': '1500',
#            '@name': '一般世帯',
#            '@unit': '世帯',
#            '@level': 1},
#           {'@code': '1501', '@name': '\u3000単身世帯', '@unit': '世帯', '@level': 2},
#           {'@code': '1502',
#            '@name': '\u3000２人以上世帯',
#            '@unit': '世帯',
#            '@level': 2}]}]},
#       'DATA_INF': {'VALUE': [{'@cat11': 'R001',
#          '@cat15': '1500',
#          '@unit': '世帯',
#          '$': '1481'},
#         {'@cat11': 'R001', '@cat15': '1501', '@unit': '世帯', '$': '656'},
#         {'@cat11': 'R001', '@cat15': '1502', '@unit': '世帯', '$': '825'},
#         {'@cat11': 'R002', '@cat15': '1500', '@unit': '世帯', '$': '8065'},
#         {'@cat11': 'R002', '@cat15': '1501', '@unit': '世帯', '$': '4034'},
#         {'@cat11': 'R002', '@cat15': '1502', '@unit': '世帯', '$': '4031'},
#         {'@cat11': 'R003', '@cat15': '1500', '@unit': '世帯', '$': '38448'},
#         {'@cat11': 'R003', '@cat15': '1501', '@unit': '世帯', '$': '20316'},
#         {'@cat11': 'R003', '@cat15': '1502', '@unit': '世帯', '$': '18132'},
#         {'@cat11': 'R010', '@cat15': '1500', '@unit': '世帯', '$': '74088'},
#         {'@cat11': 'R010', '@cat15': '1501', '@unit': '世帯', '$': '29617'},
#         {'@cat11': 'R010', '@cat15': '1502', '@unit': '世帯', '$': '44471'},
#         {'@cat11': 'R100', '@cat15': '1500', '@unit': '世帯', '$': '2767661'},
#         {'@cat11': 'R100', '@cat15': '1501', '@unit': '世帯', '$': '1003440'},
#         {'@cat11': 'R100', '@cat15': '1502', '@unit': '世帯', '$': '1764221'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '世帯',
#       'TITLE': 'TABLE05 家族類型別世帯数Ａ',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat11',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat16',
#          '@name': '家族類型Ａ',
#          'CLASS': [{'@code': '1601', '@name': '核家族世帯', '@unit': '世帯'},
#           {'@code': '1602', '@name': '\u3000夫婦のみの世帯', '@unit': '世帯'},
#           {'@code': '1603', '@name': '\u3000夫婦と子供からなる世帯', '@unit': '世帯'},
#           {'@code': '1604', '@name': '６歳未満世帯員のいる世帯', '@unit': '世帯'},
#           {'@code': '1605', '@name': '６５歳以上世帯員のいる世帯', '@unit': '世帯'}]}]},
#       'DATA_INF': {'VALUE': [{'@cat11': 'R001',
#          '@cat16': '1601',
#          '@unit': '世帯',
#          '$': '781'},
#         {'@cat11': 'R001', '@cat16': '1602', '@unit': '世帯', '$': '239'},
#         {'@cat11': 'R001', '@cat16': '1603', '@unit': '世帯', '$': '406'},
#         {'@cat11': 'R001', '@cat16': '1604', '@unit': '世帯', '$': '105'},
#         {'@cat11': 'R001', '@cat16': '1605', '@unit': '世帯', '$': '364'},
#         {'@cat11': 'R002', '@cat16': '1601', '@unit': '世帯', '$': '3697'},
#         {'@cat11': 'R002', '@cat16': '1602', '@unit': '世帯', '$': '1280'},
#         {'@cat11': 'R002', '@cat16': '1603', '@unit': '世帯', '$': '1803'},
#         {'@cat11': 'R002', '@cat16': '1604', '@unit': '世帯', '$': '447'},
#         {'@cat11': 'R002', '@cat16': '1605', '@unit': '世帯', '$': '2450'},
#         {'@cat11': 'R003', '@cat16': '1601', '@unit': '世帯', '$': '16511'},
#         {'@cat11': 'R003', '@cat16': '1602', '@unit': '世帯', '$': '5841'},
#         {'@cat11': 'R003', '@cat16': '1603', '@unit': '世帯', '$': '8150'},
#         {'@cat11': 'R003', '@cat16': '1604', '@unit': '世帯', '$': '2094'},
#         {'@cat11': 'R003', '@cat16': '1605', '@unit': '世帯', '$': '11069'},
#         {'@cat11': 'R010', '@cat16': '1601', '@unit': '世帯', '$': '40985'},
#         {'@cat11': 'R010', '@cat16': '1602', '@unit': '世帯', '$': '14737'},
#         {'@cat11': 'R010', '@cat16': '1603', '@unit': '世帯', '$': '20046'},
#         {'@cat11': 'R010', '@cat16': '1604', '@unit': '世帯', '$': '5093'},
#         {'@cat11': 'R010', '@cat16': '1605', '@unit': '世帯', '$': '26946'},
#         {'@cat11': 'R100', '@cat16': '1601', '@unit': '世帯', '$': '1572544'},
#         {'@cat11': 'R100', '@cat16': '1602', '@unit': '世帯', '$': '572435'},
#         {'@cat11': 'R100', '@cat16': '1603', '@unit': '世帯', '$': '755321'},
#         {'@cat11': 'R100', '@cat16': '1604', '@unit': '世帯', '$': '210126'},
#         {'@cat11': 'R100', '@cat16': '1605', '@unit': '世帯', '$': '1090448'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '世帯',
#       'TITLE': 'TABLE06 住宅の所有の関係別世帯数Ａ',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat11',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat17',
#          '@name': '住宅の所有の関係Ａ',
#          'CLASS': [{'@code': '1701', '@name': '持ち家世帯', '@unit': '世帯'},
#           {'@code': '1702', '@name': '民営借家世帯', '@unit': '世帯'}]}]},
#       'DATA_INF': {'VALUE': [{'@cat11': 'R001',
#          '@cat17': '1701',
#          '@unit': '世帯',
#          '$': '524'},
#         {'@cat11': 'R001', '@cat17': '1702', '@unit': '世帯', '$': '387'},
#         {'@cat11': 'R002', '@cat17': '1701', '@unit': '世帯', '$': '3642'},
#         {'@cat11': 'R002', '@cat17': '1702', '@unit': '世帯', '$': '2850'},
#         {'@cat11': 'R003', '@cat17': '1701', '@unit': '世帯', '$': '18328'},
#         {'@cat11': 'R003', '@cat17': '1702', '@unit': '世帯', '$': '14609'},
#         {'@cat11': 'R010', '@cat17': '1701', '@unit': '世帯', '$': '43254'},
#         {'@cat11': 'R010', '@cat17': '1702', '@unit': '世帯', '$': '21493'},
#         {'@cat11': 'R100', '@cat17': '1701', '@unit': '世帯', '$': '1764179'},
#         {'@cat11': 'R100', '@cat17': '1702', '@unit': '世帯', '$': '736532'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '世帯',
#       'TITLE': 'TABLE07 世帯人員別世帯数Ｂ',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat21',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat22',
#          '@name': '世帯人員Ｂ',
#          'CLASS': [{'@code': '2200',
#            '@name': '一般世帯',
#            '@unit': '世帯',
#            '@level': 1},
#           {'@code': '2201', '@name': '\u3000単身世帯', '@unit': '世帯', '@level': 2},
#           {'@code': '2202', '@name': '\u3000２人世帯', '@unit': '世帯', '@level': 2},
#           {'@code': '2203', '@name': '\u3000３人世帯', '@unit': '世帯', '@level': 2},
#           {'@code': '2204', '@name': '\u3000４人世帯', '@unit': '世帯', '@level': 2},
#           {'@code': '2205', '@name': '\u3000５人世帯', '@unit': '世帯', '@level': 2},
#           {'@code': '2206',
#            '@name': '\u3000６人以上世帯',
#            '@unit': '世帯',
#            '@level': 2}]}]},
#       'DATA_INF': {'VALUE': [{'@cat21': 'R001',
#          '@cat22': '2200',
#          '@unit': '世帯',
#          '$': '1481'},
#         {'@cat21': 'R001', '@cat22': '2201', '@unit': '世帯', '$': '656'},
#         {'@cat21': 'R001', '@cat22': '2202', '@unit': '世帯', '$': '355'},
#         {'@cat21': 'R001', '@cat22': '2203', '@unit': '世帯', '$': '226'},
#         {'@cat21': 'R001', '@cat22': '2204', '@unit': '世帯', '$': '182'},
#         {'@cat21': 'R001', '@cat22': '2205', '@unit': '世帯', '$': '50'},
#         {'@cat21': 'R001', '@cat22': '2206', '@unit': '世帯', '$': '12'},
#         {'@cat21': 'R002', '@cat22': '2200', '@unit': '世帯', '$': '8065'},
#         {'@cat21': 'R002', '@cat22': '2201', '@unit': '世帯', '$': '4034'},
#         {'@cat21': 'R002', '@cat22': '2202', '@unit': '世帯', '$': '1851'},
#         {'@cat21': 'R002', '@cat22': '2203', '@unit': '世帯', '$': '1118'},
#         {'@cat21': 'R002', '@cat22': '2204', '@unit': '世帯', '$': '819'},
#         {'@cat21': 'R002', '@cat22': '2205', '@unit': '世帯', '$': '194'},
#         {'@cat21': 'R002', '@cat22': '2206', '@unit': '世帯', '$': '49'},
#         {'@cat21': 'R003', '@cat22': '2200', '@unit': '世帯', '$': '38448'},
#         {'@cat21': 'R003', '@cat22': '2201', '@unit': '世帯', '$': '20316'},
#         {'@cat21': 'R003', '@cat22': '2202', '@unit': '世帯', '$': '8319'},
#         {'@cat21': 'R003', '@cat22': '2203', '@unit': '世帯', '$': '5040'},
#         {'@cat21': 'R003', '@cat22': '2204', '@unit': '世帯', '$': '3732'},
#         {'@cat21': 'R003', '@cat22': '2205', '@unit': '世帯', '$': '853'},
#         {'@cat21': 'R003', '@cat22': '2206', '@unit': '世帯', '$': '188'},
#         {'@cat21': 'R010', '@cat22': '2200', '@unit': '世帯', '$': '74088'},
#         {'@cat21': 'R010', '@cat22': '2201', '@unit': '世帯', '$': '29617'},
#         {'@cat21': 'R010', '@cat22': '2202', '@unit': '世帯', '$': '20449'},
#         {'@cat21': 'R010', '@cat22': '2203', '@unit': '世帯', '$': '12231'},
#         {'@cat21': 'R010', '@cat22': '2204', '@unit': '世帯', '$': '9084'},
#         {'@cat21': 'R010', '@cat22': '2205', '@unit': '世帯', '$': '2192'},
#         {'@cat21': 'R010', '@cat22': '2206', '@unit': '世帯', '$': '515'},
#         {'@cat21': 'R100', '@cat22': '2200', '@unit': '世帯', '$': '2767661'},
#         {'@cat21': 'R100', '@cat22': '2201', '@unit': '世帯', '$': '1003440'},
#         {'@cat21': 'R100', '@cat22': '2202', '@unit': '世帯', '$': '794891'},
#         {'@cat21': 'R100', '@cat22': '2203', '@unit': '世帯', '$': '484560'},
#         {'@cat21': 'R100', '@cat22': '2204', '@unit': '世帯', '$': '352307'},
#         {'@cat21': 'R100', '@cat22': '2205', '@unit': '世帯', '$': '98094'},
#         {'@cat21': 'R100', '@cat22': '2206', '@unit': '世帯', '$': '34369'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '世帯',
#       'TITLE': 'TABLE08 家族類型別世帯数Ｂ',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat21',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat23',
#          '@name': '家族類型Ｂ',
#          'CLASS': [{'@code': '2300',
#            '@name': '親族のみの世帯',
#            '@unit': '世帯',
#            '@level': 1},
#           {'@code': '2301',
#            '@name': '\u3000核家族世帯',
#            '@unit': '世帯',
#            '@level': 2},
#           {'@code': '2302',
#            '@name': '\u3000核家族以外の世帯',
#            '@unit': '世帯',
#            '@level': 2}]}]},
#       'DATA_INF': {'VALUE': [{'@cat21': 'R001',
#          '@cat23': '2300',
#          '@unit': '世帯',
#          '$': '814'},
#         {'@cat21': 'R001', '@cat23': '2301', '@unit': '世帯', '$': '781'},
#         {'@cat21': 'R001', '@cat23': '2302', '@unit': '世帯', '$': '33'},
#         {'@cat21': 'R002', '@cat23': '2300', '@unit': '世帯', '$': '3943'},
#         {'@cat21': 'R002', '@cat23': '2301', '@unit': '世帯', '$': '3697'},
#         {'@cat21': 'R002', '@cat23': '2302', '@unit': '世帯', '$': '246'},
#         {'@cat21': 'R003', '@cat23': '2300', '@unit': '世帯', '$': '17589'},
#         {'@cat21': 'R003', '@cat23': '2301', '@unit': '世帯', '$': '16511'},
#         {'@cat21': 'R003', '@cat23': '2302', '@unit': '世帯', '$': '1078'},
#         {'@cat21': 'R010', '@cat23': '2300', '@unit': '世帯', '$': '43532'},
#         {'@cat21': 'R010', '@cat23': '2301', '@unit': '世帯', '$': '40985'},
#         {'@cat21': 'R010', '@cat23': '2302', '@unit': '世帯', '$': '2547'},
#         {'@cat21': 'R100', '@cat23': '2300', '@unit': '世帯', '$': '1730277'},
#         {'@cat21': 'R100', '@cat23': '2301', '@unit': '世帯', '$': '1572544'},
#         {'@cat21': 'R100', '@cat23': '2302', '@unit': '世帯', '$': '157733'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '世帯',
#       'TITLE': 'TABLE09 家族類型別世帯数Ｃ',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat21',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat24',
#          '@name': '家族類型Ｃ',
#          'CLASS': [{'@code': '2401', '@name': '６歳未満世帯員のいる世帯', '@unit': '世帯'},
#           {'@code': '2402', '@name': '１８歳未満世帯員のいる世帯', '@unit': '世帯'},
#           {'@code': '2403', '@name': '６５歳以上世帯員のいる世帯', '@unit': '世帯'}]}]},
#       'DATA_INF': {'VALUE': [{'@cat21': 'R001',
#          '@cat24': '2401',
#          '@unit': '世帯',
#          '$': '105'},
#         {'@cat21': 'R001', '@cat24': '2402', '@unit': '世帯', '$': '292'},
#         {'@cat21': 'R001', '@cat24': '2403', '@unit': '世帯', '$': '364'},
#         {'@cat21': 'R002', '@cat24': '2401', '@unit': '世帯', '$': '447'},
#         {'@cat21': 'R002', '@cat24': '2402', '@unit': '世帯', '$': '1209'},
#         {'@cat21': 'R002', '@cat24': '2403', '@unit': '世帯', '$': '2450'},
#         {'@cat21': 'R003', '@cat24': '2401', '@unit': '世帯', '$': '2094'},
#         {'@cat21': 'R003', '@cat24': '2402', '@unit': '世帯', '$': '5666'},
#         {'@cat21': 'R003', '@cat24': '2403', '@unit': '世帯', '$': '11069'},
#         {'@cat21': 'R010', '@cat24': '2401', '@unit': '世帯', '$': '5093'},
#         {'@cat21': 'R010', '@cat24': '2402', '@unit': '世帯', '$': '13868'},
#         {'@cat21': 'R010', '@cat24': '2403', '@unit': '世帯', '$': '26946'},
#         {'@cat21': 'R100', '@cat24': '2401', '@unit': '世帯', '$': '210126'},
#         {'@cat21': 'R100', '@cat24': '2402', '@unit': '世帯', '$': '541923'},
#         {'@cat21': 'R100', '@cat24': '2403', '@unit': '世帯', '$': '1090448'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '世帯',
#       'TITLE': 'TABLE10 住宅の建て方別世帯数',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat21',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat25',
#          '@name': '住宅の建て方',
#          'CLASS': [{'@code': '2501', '@name': '主世帯', '@unit': '世帯'},
#           {'@code': '2502', '@name': '一戸建', '@unit': '世帯'},
#           {'@code': '2503', '@name': '長屋建', '@unit': '世帯'},
#           {'@code': '2504', '@name': '共同住宅', '@unit': '世帯'},
#           {'@code': '2505', '@name': '\u3000１～２階建', '@unit': '世帯'},
#           {'@code': '2506', '@name': '\u3000３～５階建', '@unit': '世帯'},
#           {'@code': '2507', '@name': '\u3000６～１０階建', '@unit': '世帯'},
#           {'@code': '2508', '@name': '\u3000１１階建以上', '@unit': '世帯'},
#           {'@code': '2509', '@name': 'その他', '@unit': '世帯'}]}]},
#       'DATA_INF': {'VALUE': [{'@cat21': 'R001',
#          '@cat25': '2501',
#          '@unit': '世帯',
#          '$': '1464'},
#         {'@cat21': 'R001', '@cat25': '2502', '@unit': '世帯', '$': '224'},
#         {'@cat21': 'R001', '@cat25': '2503', '@unit': '世帯', '$': '4'},
#         {'@cat21': 'R001', '@cat25': '2504', '@unit': '世帯', '$': '1235'},
#         {'@cat21': 'R001', '@cat25': '2505', '@unit': '世帯', '$': '205'},
#         {'@cat21': 'R001', '@cat25': '2506', '@unit': '世帯', '$': '264'},
#         {'@cat21': 'R001', '@cat25': '2507', '@unit': '世帯', '$': '559'},
#         {'@cat21': 'R001', '@cat25': '2508', '@unit': '世帯', '$': '207'},
#         {'@cat21': 'R001', '@cat25': '2509', '@unit': '世帯', '$': '0'},
#         {'@cat21': 'R002', '@cat25': '2501', '@unit': '世帯', '$': '7838'},
#         {'@cat21': 'R002', '@cat25': '2502', '@unit': '世帯', '$': '2067'},
#         {'@cat21': 'R002', '@cat25': '2503', '@unit': '世帯', '$': '71'},
#         {'@cat21': 'R002', '@cat25': '2504', '@unit': '世帯', '$': '5694'},
#         {'@cat21': 'R002', '@cat25': '2505', '@unit': '世帯', '$': '1639'},
#         {'@cat21': 'R002', '@cat25': '2506', '@unit': '世帯', '$': '1528'},
#         {'@cat21': 'R002', '@cat25': '2507', '@unit': '世帯', '$': '1773'},
#         {'@cat21': 'R002', '@cat25': '2508', '@unit': '世帯', '$': '753'},
#         {'@cat21': 'R002', '@cat25': '2509', '@unit': '世帯', '$': '5'},
#         {'@cat21': 'R003', '@cat25': '2501', '@unit': '世帯', '$': '37732'},
#         {'@cat21': 'R003', '@cat25': '2502', '@unit': '世帯', '$': '10074'},
#         {'@cat21': 'R003', '@cat25': '2503', '@unit': '世帯', '$': '257'},
#         {'@cat21': 'R003', '@cat25': '2504', '@unit': '世帯', '$': '27359'},
#         {'@cat21': 'R003', '@cat25': '2505', '@unit': '世帯', '$': '7447'},
#         {'@cat21': 'R003', '@cat25': '2506', '@unit': '世帯', '$': '10693'},
#         {'@cat21': 'R003', '@cat25': '2507', '@unit': '世帯', '$': '6263'},
#         {'@cat21': 'R003', '@cat25': '2508', '@unit': '世帯', '$': '2956'},
#         {'@cat21': 'R003', '@cat25': '2509', '@unit': '世帯', '$': '42'},
#         {'@cat21': 'R010', '@cat25': '2501', '@unit': '世帯', '$': '72271'},
#         {'@cat21': 'R010', '@cat25': '2502', '@unit': '世帯', '$': '24400'},
#         {'@cat21': 'R010', '@cat25': '2503', '@unit': '世帯', '$': '683'},
#         {'@cat21': 'R010', '@cat25': '2504', '@unit': '世帯', '$': '47116'},
#         {'@cat21': 'R010', '@cat25': '2505', '@unit': '世帯', '$': '11560'},
#         {'@cat21': 'R010', '@cat25': '2506', '@unit': '世帯', '$': '17529'},
#         {'@cat21': 'R010', '@cat25': '2507', '@unit': '世帯', '$': '8744'},
#         {'@cat21': 'R010', '@cat25': '2508', '@unit': '世帯', '$': '9283'},
#         {'@cat21': 'R010', '@cat25': '2509', '@unit': '世帯', '$': '72'},
#         {'@cat21': 'R100', '@cat25': '2501', '@unit': '世帯', '$': '2691499'},
#         {'@cat21': 'R100', '@cat25': '2502', '@unit': '世帯', '$': '1418710'},
#         {'@cat21': 'R100', '@cat25': '2503', '@unit': '世帯', '$': '32394'},
#         {'@cat21': 'R100', '@cat25': '2504', '@unit': '世帯', '$': '1238355'},
#         {'@cat21': 'R100', '@cat25': '2505', '@unit': '世帯', '$': '383096'},
#         {'@cat21': 'R100', '@cat25': '2506', '@unit': '世帯', '$': '442507'},
#         {'@cat21': 'R100', '@cat25': '2507', '@unit': '世帯', '$': '226650'},
#         {'@cat21': 'R100', '@cat25': '2508', '@unit': '世帯', '$': '186102'},
#         {'@cat21': 'R100', '@cat25': '2509', '@unit': '世帯', '$': '2040'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '世帯',
#       'TITLE': 'TABLE11 住宅の所有の関係別世帯数Ｂ',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat21',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat26',
#          '@name': '住宅の所有の関係Ｂ',
#          'CLASS': [{'@code': '2601', '@name': '住宅に住む一般世帯', '@unit': '世帯'},
#           {'@code': '2602', '@name': '持ち家', '@unit': '世帯'},
#           {'@code': '2603', '@name': '民営の借家', '@unit': '世帯'}]}]},
#       'DATA_INF': {'VALUE': [{'@cat21': 'R001',
#          '@cat26': '2601',
#          '@unit': '世帯',
#          '$': '1474'},
#         {'@cat21': 'R001', '@cat26': '2602', '@unit': '世帯', '$': '524'},
#         {'@cat21': 'R001', '@cat26': '2603', '@unit': '世帯', '$': '387'},
#         {'@cat21': 'R002', '@cat26': '2601', '@unit': '世帯', '$': '7909'},
#         {'@cat21': 'R002', '@cat26': '2602', '@unit': '世帯', '$': '3642'},
#         {'@cat21': 'R002', '@cat26': '2603', '@unit': '世帯', '$': '2850'},
#         {'@cat21': 'R003', '@cat26': '2601', '@unit': '世帯', '$': '38073'},
#         {'@cat21': 'R003', '@cat26': '2602', '@unit': '世帯', '$': '18328'},
#         {'@cat21': 'R003', '@cat26': '2603', '@unit': '世帯', '$': '14609'},
#         {'@cat21': 'R010', '@cat26': '2601', '@unit': '世帯', '$': '73099'},
#         {'@cat21': 'R010', '@cat26': '2602', '@unit': '世帯', '$': '43254'},
#         {'@cat21': 'R010', '@cat26': '2603', '@unit': '世帯', '$': '21493'},
#         {'@cat21': 'R100', '@cat26': '2601', '@unit': '世帯', '$': '2726485'},
#         {'@cat21': 'R100', '@cat26': '2602', '@unit': '世帯', '$': '1764179'},
#         {'@cat21': 'R100', '@cat26': '2603', '@unit': '世帯', '$': '736532'}]}},
#      {'STATISTICS_NAME': '令和2年国勢調査',
#       'STAT_KIND': '人口',
#       'TITLE': 'TABLE12 年齢（５歳階級）男女別人口数',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'cat31',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat32',
#          '@name': '男女',
#          'CLASS': [{'@code': '3200', '@name': '男女計', '@level': 1},
#           {'@code': '3201', '@name': '男', '@level': 2},
#           {'@code': '3202', '@name': '女', '@level': 2}]},
#         {'@id': 'cat33',
#          '@name': '年齢（５歳階級）',
#          'CLASS': [{'@code': '3300', '@name': '総人口', '@unit': '人'},
#           {'@code': '3301', '@name': '4歳以下', '@unit': '人'},
#           {'@code': '3302', '@name': '5～9歳', '@unit': '人'},
#           {'@code': '3303', '@name': '10～14歳', '@unit': '人'},
#           {'@code': '3304', '@name': '15～19歳', '@unit': '人'},
#           {'@code': '3305', '@name': '20～24歳', '@unit': '人'},
#           {'@code': '3306', '@name': '25～29歳', '@unit': '人'},
#           {'@code': '3307', '@name': '30～34歳', '@unit': '人'},
#           {'@code': '3308', '@name': '35～39歳', '@unit': '人'},
#           {'@code': '3309', '@name': '40～44歳', '@unit': '人'},
#           {'@code': '3310', '@name': '45～49歳', '@unit': '人'},
#           {'@code': '3311', '@name': '50～54歳', '@unit': '人'},
#           {'@code': '3312', '@name': '55～59歳', '@unit': '人'},
#           {'@code': '3313', '@name': '60～64歳', '@unit': '人'},
#           {'@code': '3314', '@name': '65～69歳', '@unit': '人'},
#           {'@code': '3315', '@name': '70～74歳', '@unit': '人'},
#           {'@code': '3316', '@name': '75歳以上', '@unit': '人'}]}]},
#       'DATA_INF': {'VALUE': [{'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3300',
#          '@unit': '人',
#          '$': '3151'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3301',
#          '@unit': '人',
#          '$': '109'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3302',
#          '@unit': '人',
#          '$': '138'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3303',
#          '@unit': '人',
#          '$': '159'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3304',
#          '@unit': '人',
#          '$': '192'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3305',
#          '@unit': '人',
#          '$': '252'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3306',
#          '@unit': '人',
#          '$': '158'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3307',
#          '@unit': '人',
#          '$': '127'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3308',
#          '@unit': '人',
#          '$': '161'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3309',
#          '@unit': '人',
#          '$': '181'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3310',
#          '@unit': '人',
#          '$': '278'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3311',
#          '@unit': '人',
#          '$': '206'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3312',
#          '@unit': '人',
#          '$': '213'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3313',
#          '@unit': '人',
#          '$': '181'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3314',
#          '@unit': '人',
#          '$': '143'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3315',
#          '@unit': '人',
#          '$': '157'},
#         {'@cat31': 'R001',
#          '@cat32': '3200',
#          '@cat33': '3316',
#          '@unit': '人',
#          '$': '269'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3300',
#          '@unit': '人',
#          '$': '1588'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3301',
#          '@unit': '人',
#          '$': '56'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3302',
#          '@unit': '人',
#          '$': '66'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3303',
#          '@unit': '人',
#          '$': '83'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3304',
#          '@unit': '人',
#          '$': '102'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3305',
#          '@unit': '人',
#          '$': '158'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3306',
#          '@unit': '人',
#          '$': '83'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3307',
#          '@unit': '人',
#          '$': '72'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3308',
#          '@unit': '人',
#          '$': '77'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3309',
#          '@unit': '人',
#          '$': '87'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3310',
#          '@unit': '人',
#          '$': '144'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3311',
#          '@unit': '人',
#          '$': '99'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3312',
#          '@unit': '人',
#          '$': '98'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3313',
#          '@unit': '人',
#          '$': '91'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3314',
#          '@unit': '人',
#          '$': '66'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3315',
#          '@unit': '人',
#          '$': '70'},
#         {'@cat31': 'R001',
#          '@cat32': '3201',
#          '@cat33': '3316',
#          '@unit': '人',
#          '$': '104'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3300',
#          '@unit': '人',
#          '$': '1563'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3301',
#          '@unit': '人',
#          '$': '52'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3302',
#          '@unit': '人',
#          '$': '72'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3303',
#          '@unit': '人',
#          '$': '76'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3304',
#          '@unit': '人',
#          '$': '90'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3305',
#          '@unit': '人',
#          '$': '94'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3306',
#          '@unit': '人',
#          '$': '75'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3307',
#          '@unit': '人',
#          '$': '56'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3308',
#          '@unit': '人',
#          '$': '84'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3309',
#          '@unit': '人',
#          '$': '95'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3310',
#          '@unit': '人',
#          '$': '134'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3311',
#          '@unit': '人',
#          '$': '107'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3312',
#          '@unit': '人',
#          '$': '116'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3313',
#          '@unit': '人',
#          '$': '90'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3314',
#          '@unit': '人',
#          '$': '76'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3315',
#          '@unit': '人',
#          '$': '87'},
#         {'@cat31': 'R001',
#          '@cat32': '3202',
#          '@cat33': '3316',
#          '@unit': '人',
#          '$': '165'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3300',
#          '@unit': '人',
#          '$': '15776'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3301',
#          '@unit': '人',
#          '$': '460'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3302',
#          '@unit': '人',
#          '$': '571'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3303',
#          '@unit': '人',
#          '$': '636'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3304',
#          '@unit': '人',
#          '$': '831'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3305',
#          '@unit': '人',
#          '$': '1298'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3306',
#          '@unit': '人',
#          '$': '680'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3307',
#          '@unit': '人',
#          '$': '653'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3308',
#          '@unit': '人',
#          '$': '766'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3309',
#          '@unit': '人',
#          '$': '890'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3310',
#          '@unit': '人',
#          '$': '1102'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3311',
#          '@unit': '人',
#          '$': '961'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3312',
#          '@unit': '人',
#          '$': '942'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3313',
#          '@unit': '人',
#          '$': '814'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3314',
#          '@unit': '人',
#          '$': '890'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3315',
#          '@unit': '人',
#          '$': '966'},
#         {'@cat31': 'R002',
#          '@cat32': '3200',
#          '@cat33': '3316',
#          '@unit': '人',
#          '$': '1822'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3300',
#          '@unit': '人',
#          '$': '8034'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3301',
#          '@unit': '人',
#          '$': '229'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3302',
#          '@unit': '人',
#          '$': '289'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3303',
#          '@unit': '人',
#          '$': '334'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3304',
#          '@unit': '人',
#          '$': '446'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3305',
#          '@unit': '人',
#          '$': '809'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3306',
#          '@unit': '人',
#          '$': '365'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3307',
#          '@unit': '人',
#          '$': '355'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3308',
#          '@unit': '人',
#          '$': '368'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3309',
#          '@unit': '人',
#          '$': '453'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3310',
#          '@unit': '人',
#          '$': '554'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3311',
#          '@unit': '人',
#          '$': '478'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3312',
#          '@unit': '人',
#          '$': '464'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3313',
#          '@unit': '人',
#          '$': '384'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3314',
#          '@unit': '人',
#          '$': '420'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3315',
#          '@unit': '人',
#          '$': '444'},
#         {'@cat31': 'R002',
#          '@cat32': '3201',
#          '@cat33': '3316',
#          '@unit': '人',
#          '$': '761'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3300',
#          '@unit': '人',
#          '$': '7742'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3301',
#          '@unit': '人',
#          '$': '231'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3302',
#          '@unit': '人',
#          '$': '282'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3303',
#          '@unit': '人',
#          '$': '303'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3304',
#          '@unit': '人',
#          '$': '385'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3305',
#          '@unit': '人',
#          '$': '488'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3306',
#          '@unit': '人',
#          '$': '316'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3307',
#          '@unit': '人',
#          '$': '298'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3308',
#          '@unit': '人',
#          '$': '398'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3309',
#          '@unit': '人',
#          '$': '436'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3310',
#          '@unit': '人',
#          '$': '548'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3311',
#          '@unit': '人',
#          '$': '484'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3312',
#          '@unit': '人',
#          '$': '478'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3313',
#          '@unit': '人',
#          '$': '430'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3314',
#          '@unit': '人',
#          '$': '470'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3315',
#          '@unit': '人',
#          '$': '522'},
#         {'@cat31': 'R002',
#          '@cat32': '3202',
#          '@cat33': '3316',
#          '@unit': '人',
#          '$': '1061'},
#         {'@cat31': 'R003',
#          '@cat32': '3200',
#          '@cat33': '3300',
#          '@unit': '人',
#          '$': '73461'},
#         {'@cat31': 'R003',
#          '@cat32': '3200',
#          '@cat33': '3301',
#          '@unit': '人',
#          '$': '2112'},
#         {'@cat31': 'R003',
#          '@cat32': '3200',
#          '@cat33': '3302',
#          '@unit': '人',
#          '$': '2637'},
#         {'@cat31': 'R003',
#          '@cat32': '3200',
#          '@cat33': '3303',
#          '@unit': '人',
#          '$': '2910'},
#         {'@cat31': 'R003',
#          '@cat32': '3200',
#          '@cat33': '3304',
#          '@unit': '人',
#          '$': '3408'},
#         {'@cat31': 'R003',
#          '@cat32': '3200',
#          '@cat33': '3305',
#          '@unit': '人',
#          '$': '5173'},
#         {'@cat31': 'R003',
#          '@cat32': '3200',
#          '@cat33': '3306',
#          '@unit': '人',
#          '$': '3278'},
#         {'@cat31': 'R003',
#          '@cat32': '3200',
#          '@cat33': '3307',
#          '@unit': '人',
#          '$': '3186'},
#         {'@cat31': 'R003',
#          '@cat32': '3200',
# ...
#          '@unit': '事業所',
#          '$': '260'},
#         {'@tab': '1',
#          '@cat41': 'R003',
#          '@cat44': '4412',
#          '@unit': '事業所',
#          '$': '11'},
#         {'@tab': '1',
#          '@cat41': 'R003',
#          '@cat44': '4413',
#          '@unit': '事業所',
#          '$': '151'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4401',
#          '@unit': '人',
#          '$': '1'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4402',
#          '@unit': '人',
#          '$': '160'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4403',
#          '@unit': '人',
#          '$': '554'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4404',
#          '@unit': '人',
#          '$': '4676'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4405',
#          '@unit': '人',
#          '$': '530'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4406',
#          '@unit': '人',
#          '$': '1030'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4407',
#          '@unit': '人',
#          '$': '2696'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4408',
#          '@unit': '人',
#          '$': '2602'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4409',
#          '@unit': '人',
#          '$': '974'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4410',
#          '@unit': '人',
#          '$': '5094'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4411',
#          '@unit': '人',
#          '$': '3824'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4412',
#          '@unit': '人',
#          '$': '65'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat44': '4413',
#          '@unit': '人',
#          '$': '3234'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4401',
#          '@unit': '事業所',
#          '$': '2'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4402',
#          '@unit': '事業所',
#          '$': '23'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4403',
#          '@unit': '事業所',
#          '$': '133'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4404',
#          '@unit': '事業所',
#          '$': '1021'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4405',
#          '@unit': '事業所',
#          '$': '45'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4406',
#          '@unit': '事業所',
#          '$': '428'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4407',
#          '@unit': '事業所',
#          '$': '178'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4408',
#          '@unit': '事業所',
#          '$': '468'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4409',
#          '@unit': '事業所',
#          '$': '403'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4410',
#          '@unit': '事業所',
#          '$': '178'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4411',
#          '@unit': '事業所',
#          '$': '439'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4412',
#          '@unit': '事業所',
#          '$': '14'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat44': '4413',
#          '@unit': '事業所',
#          '$': '232'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4401',
#          '@unit': '人',
#          '$': '5'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4402',
#          '@unit': '人',
#          '$': '109'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4403',
#          '@unit': '人',
#          '$': '3168'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4404',
#          '@unit': '人',
#          '$': '11495'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4405',
#          '@unit': '人',
#          '$': '712'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4406',
#          '@unit': '人',
#          '$': '1557'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4407',
#          '@unit': '人',
#          '$': '3015'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4408',
#          '@unit': '人',
#          '$': '3852'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4409',
#          '@unit': '人',
#          '$': '2299'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4410',
#          '@unit': '人',
#          '$': '4833'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4411',
#          '@unit': '人',
#          '$': '6138'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4412',
#          '@unit': '人',
#          '$': '90'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat44': '4413',
#          '@unit': '人',
#          '$': '2945'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4401',
#          '@unit': '事業所',
#          '$': '131'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4402',
#          '@unit': '事業所',
#          '$': '1457'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4403',
#          '@unit': '事業所',
#          '$': '5504'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4404',
#          '@unit': '事業所',
#          '$': '47017'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4405',
#          '@unit': '事業所',
#          '$': '2821'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4406',
#          '@unit': '事業所',
#          '$': '12233'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4407',
#          '@unit': '事業所',
#          '$': '6831'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4408',
#          '@unit': '事業所',
#          '$': '25104'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4409',
#          '@unit': '事業所',
#          '$': '19310'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4410',
#          '@unit': '事業所',
#          '$': '6903'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4411',
#          '@unit': '事業所',
#          '$': '16820'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4412',
#          '@unit': '事業所',
#          '$': '981'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat44': '4413',
#          '@unit': '事業所',
#          '$': '11573'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4401',
#          '@unit': '人',
#          '$': '6109'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4402',
#          '@unit': '人',
#          '$': '28794'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4403',
#          '@unit': '人',
#          '$': '167927'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4404',
#          '@unit': '人',
#          '$': '443104'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4405',
#          '@unit': '人',
#          '$': '48883'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4406',
#          '@unit': '人',
#          '$': '53857'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4407',
#          '@unit': '人',
#          '$': '51962'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4408',
#          '@unit': '人',
#          '$': '218655'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4409',
#          '@unit': '人',
#          '$': '131916'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4410',
#          '@unit': '人',
#          '$': '76240'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4411',
#          '@unit': '人',
#          '$': '292342'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4412',
#          '@unit': '人',
#          '$': '17143'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat44': '4413',
#          '@unit': '人',
#          '$': '180630'}]}},
#      {'STATISTICS_NAME': '平成28年経済センサス－活動調査',
#       'STAT_KIND': '産業',
#       'TITLE': 'TABLE16 従業者規模別\u3000従業者・事業所数',
#       'CLASS_INF': {'CLASS_OBJ': [{'@id': 'tab',
#          '@name': '表章項目',
#          'CLASS': [{'@code': '1', '@name': '事業所数', '@unit': '事業所'},
#           {'@code': '2', '@name': '従業者数', '@unit': '人'}]},
#         {'@id': 'cat41',
#          '@name': '集計範囲',
#          'CLASS': [{'@code': 'R001', '@name': '1次エリア'},
#           {'@code': 'R002', '@name': '2次エリア'},
#           {'@code': 'R003', '@name': '3次エリア'},
#           {'@code': 'R010', '@name': '千葉市稲毛区'},
#           {'@code': 'R100', '@name': '千葉県'}]},
#         {'@id': 'cat45',
#          '@name': '従業者規模',
#          'CLASS': [{'@code': '4501', '@name': '１～４人'},
#           {'@code': '4502', '@name': '５～９人'},
#           {'@code': '4503', '@name': '１０～１９人'},
#           {'@code': '4504', '@name': '２０～２９人'},
#           {'@code': '4505', '@name': '３０人以上'},
#           {'@code': '4506', '@name': '出向・派遣従業者のみ'}]}]},
#       'DATA_INF': {'VALUE': [{'@tab': '1',
#          '@cat41': 'R001',
#          '@cat45': '4501',
#          '@unit': '事業所',
#          '$': '21'},
#         {'@tab': '1',
#          '@cat41': 'R001',
#          '@cat45': '4502',
#          '@unit': '事業所',
#          '$': '10'},
#         {'@tab': '1',
#          '@cat41': 'R001',
#          '@cat45': '4503',
#          '@unit': '事業所',
#          '$': '5'},
#         {'@tab': '1',
#          '@cat41': 'R001',
#          '@cat45': '4504',
#          '@unit': '事業所',
#          '$': '1'},
#         {'@tab': '1',
#          '@cat41': 'R001',
#          '@cat45': '4505',
#          '@unit': '事業所',
#          '$': '3'},
#         {'@tab': '1',
#          '@cat41': 'R001',
#          '@cat45': '4506',
#          '@unit': '事業所',
#          '$': '0'},
#         {'@tab': '2',
#          '@cat41': 'R001',
#          '@cat45': '4501',
#          '@unit': '人',
#          '$': '40'},
#         {'@tab': '2',
#          '@cat41': 'R001',
#          '@cat45': '4502',
#          '@unit': '人',
#          '$': '75'},
#         {'@tab': '2',
#          '@cat41': 'R001',
#          '@cat45': '4503',
#          '@unit': '人',
#          '$': '73'},
#         {'@tab': '2',
#          '@cat41': 'R001',
#          '@cat45': '4504',
#          '@unit': '人',
#          '$': '17'},
#         {'@tab': '2',
#          '@cat41': 'R001',
#          '@cat45': '4505',
#          '@unit': '人',
#          '$': '319'},
#         {'@tab': '1',
#          '@cat41': 'R002',
#          '@cat45': '4501',
#          '@unit': '事業所',
#          '$': '243'},
#         {'@tab': '1',
#          '@cat41': 'R002',
#          '@cat45': '4502',
#          '@unit': '事業所',
#          '$': '69'},
#         {'@tab': '1',
#          '@cat41': 'R002',
#          '@cat45': '4503',
#          '@unit': '事業所',
#          '$': '36'},
#         {'@tab': '1',
#          '@cat41': 'R002',
#          '@cat45': '4504',
#          '@unit': '事業所',
#          '$': '11'},
#         {'@tab': '1',
#          '@cat41': 'R002',
#          '@cat45': '4505',
#          '@unit': '事業所',
#          '$': '28'},
#         {'@tab': '1',
#          '@cat41': 'R002',
#          '@cat45': '4506',
#          '@unit': '事業所',
#          '$': '0'},
#         {'@tab': '2',
#          '@cat41': 'R002',
#          '@cat45': '4501',
#          '@unit': '人',
#          '$': '475'},
#         {'@tab': '2',
#          '@cat41': 'R002',
#          '@cat45': '4502',
#          '@unit': '人',
#          '$': '462'},
#         {'@tab': '2',
#          '@cat41': 'R002',
#          '@cat45': '4503',
#          '@unit': '人',
#          '$': '483'},
#         {'@tab': '2',
#          '@cat41': 'R002',
#          '@cat45': '4504',
#          '@unit': '人',
#          '$': '257'},
#         {'@tab': '2',
#          '@cat41': 'R002',
#          '@cat45': '4505',
#          '@unit': '人',
#          '$': '3135'},
#         {'@tab': '1',
#          '@cat41': 'R003',
#          '@cat45': '4501',
#          '@unit': '事業所',
#          '$': '1391'},
#         {'@tab': '1',
#          '@cat41': 'R003',
#          '@cat45': '4502',
#          '@unit': '事業所',
#          '$': '499'},
#         {'@tab': '1',
#          '@cat41': 'R003',
#          '@cat45': '4503',
#          '@unit': '事業所',
#          '$': '272'},
#         {'@tab': '1',
#          '@cat41': 'R003',
#          '@cat45': '4504',
#          '@unit': '事業所',
#          '$': '97'},
#         {'@tab': '1',
#          '@cat41': 'R003',
#          '@cat45': '4505',
#          '@unit': '事業所',
#          '$': '140'},
#         {'@tab': '1',
#          '@cat41': 'R003',
#          '@cat45': '4506',
#          '@unit': '事業所',
#          '$': '13'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat45': '4501',
#          '@unit': '人',
#          '$': '2842'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat45': '4502',
#          '@unit': '人',
#          '$': '3318'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat45': '4503',
#          '@unit': '人',
#          '$': '3678'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat45': '4504',
#          '@unit': '人',
#          '$': '2294'},
#         {'@tab': '2',
#          '@cat41': 'R003',
#          '@cat45': '4505',
#          '@unit': '人',
#          '$': '15148'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat45': '4501',
#          '@unit': '事業所',
#          '$': '2083'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat45': '4502',
#          '@unit': '事業所',
#          '$': '901'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat45': '4503',
#          '@unit': '事業所',
#          '$': '571'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat45': '4504',
#          '@unit': '事業所',
#          '$': '227'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat45': '4505',
#          '@unit': '事業所',
#          '$': '310'},
#         {'@tab': '1',
#          '@cat41': 'R010',
#          '@cat45': '4506',
#          '@unit': '事業所',
#          '$': '29'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat45': '4501',
#          '@unit': '人',
#          '$': '4420'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat45': '4502',
#          '@unit': '人',
#          '$': '5936'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat45': '4503',
#          '@unit': '人',
#          '$': '7726'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat45': '4504',
#          '@unit': '人',
#          '$': '5345'},
#         {'@tab': '2',
#          '@cat41': 'R010',
#          '@cat45': '4505',
#          '@unit': '人',
#          '$': '24567'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat45': '4501',
#          '@unit': '事業所',
#          '$': '102398'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat45': '4502',
#          '@unit': '事業所',
#          '$': '38218'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat45': '4503',
#          '@unit': '事業所',
#          '$': '24997'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat45': '4504',
#          '@unit': '事業所',
#          '$': '9308'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat45': '4505',
#          '@unit': '事業所',
#          '$': '12666'},
#         {'@tab': '1',
#          '@cat41': 'R100',
#          '@cat45': '4506',
#          '@unit': '事業所',
#          '$': '1153'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat45': '4501',
#          '@unit': '人',
#          '$': '221867'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat45': '4502',
#          '@unit': '人',
#          '$': '251685'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat45': '4503',
#          '@unit': '人',
#          '$': '338750'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat45': '4504',
#          '@unit': '人',
#          '$': '220987'},
#         {'@tab': '2',
#          '@cat41': 'R100',
#          '@cat45': '4505',
#          '@unit': '人',
#          '$': '1080970'}]}}]}]}}

# %%
#性別別人口
Gender_pop = result['GET_SUMMARY']['DATASET_INF'][0]['TABLE_INF'][0]['DATA_INF']['VALUE']
Gender_pop2 = [{key: value for key, value in entry.items() if key not in ['@cat11', '@cat12']} for entry in Gender_pop]
Gender_pop3 = [entry['$'] for entry in Gender_pop2]
# リストを3つずつに分割
list_Gender = [Gender_pop3[i:i+3] for i in range(0, len(Gender_pop3), 3)]
# DataFrameに変換
df_Gender = pd.DataFrame(list_Gender, columns=['総人口', '男性人口', '女性人口'])
display(df_Gender)
# Out:
#        総人口     男性人口     女性人口
# 0     3151     1588     1563
# 1    15776     8034     7742
# 2    73461    36662    36799
# 3   160582    80345    80237
# 4  6284480  3117987  3166493

# %%
#年齢別人口
Age_pop = result['GET_SUMMARY']['DATASET_INF'][0]['TABLE_INF'][1]['DATA_INF']['VALUE']
Age_pop2 = [{key: value for key, value in entry.items() if key not in ['@cat11', '@cat13']} for entry in Age_pop]
Age_pop3 = [entry['$'] for entry in Age_pop2]
# リストを3つずつに分割
list_Age = [Age_pop3[i:i+16] for i in range(0, len(Age_pop3), 16)]
# DataFrameに変換
df_Age = pd.DataFrame(list_Age, columns=['4 歳以下', '5～9 歳', '10～14 歳', '15～19 歳', '20～24 歳', '25～29 歳', '30～34 歳','35～39 歳', '40～44 歳','45～49 歳', '50～54 歳','55～59 歳', '60～64 歳','65～69 歳', '70～74 歳','75 歳以上'])
display(df_Age)
# Out:
#     4 歳以下   5～9 歳 10～14 歳 15～19 歳 20～24 歳 25～29 歳 30～34 歳 35～39 歳 40～44 歳
# 0     109     138     159     192     252     158     127     161     181  \
# 1     460     571     636     831    1298     680     653     766     890
# 2    2112    2637    2910    3408    5173    3278    3186    3720    4420
# 3    5273    6328    6977    7671    8592    7035    7416    8947   10536
# 4  221053  248798  264645  281545  316219  311470  329858  372869  423399
#
#   45～49 歳 50～54 歳 55～59 歳 60～64 歳 65～69 歳 70～74 歳  75 歳以上
# 0     278     206     213     181     143     157     269
# 1    1102     961     942     814     890     966    1822
# 2    5268    4714    4012    3589    3750    4350    8786
# 3   12996   11391    9375    8330    9234   11050   21491
# 4  507856  447662  382032  342781  387685  452539  859767

# %%
# DataFrameを横に結合
df = pd.concat([df_Gender, df_Age], axis=1)
display(df)
# Out:
#        総人口     男性人口     女性人口   4 歳以下   5～9 歳 10～14 歳 15～19 歳 20～24 歳 25～29 歳
# 0     3151     1588     1563     109     138     159     192     252     158  \
# 1    15776     8034     7742     460     571     636     831    1298     680
# 2    73461    36662    36799    2112    2637    2910    3408    5173    3278
# 3   160582    80345    80237    5273    6328    6977    7671    8592    7035
# 4  6284480  3117987  3166493  221053  248798  264645  281545  316219  311470
#
#   30～34 歳 35～39 歳 40～44 歳 45～49 歳 50～54 歳 55～59 歳 60～64 歳 65～69 歳 70～74 歳
# 0     127     161     181     278     206     213     181     143     157  \
# 1     653     766     890    1102     961     942     814     890     966
# 2    3186    3720    4420    5268    4714    4012    3589    3750    4350
# 3    7416    8947   10536   12996   11391    9375    8330    9234   11050
# 4  329858  372869  423399  507856  447662  382032  342781  387685  452539
#
#    75 歳以上
# 0     269
# 1    1822
# 2    8786
# 3   21491
# 4  859767

# %%
# 新しいカラムを作成
item_column = ['徒歩10分圏内', '徒歩20分圏内', '徒歩40分圏内', '区', '都道府県']

# 新しいカラムをDataFrameの先頭列に追加
df.insert(0, '項目', item_column)
display(df)
# Out:
#         項目      総人口     男性人口     女性人口   4 歳以下   5～9 歳 10～14 歳 15～19 歳 20～24 歳
# 0  徒歩10分圏内     3151     1588     1563     109     138     159     192     252  \
# 1  徒歩20分圏内    15776     8034     7742     460     571     636     831    1298
# 2  徒歩40分圏内    73461    36662    36799    2112    2637    2910    3408    5173
# 3        区   160582    80345    80237    5273    6328    6977    7671    8592
# 4     都道府県  6284480  3117987  3166493  221053  248798  264645  281545  316219
#
#   25～29 歳 30～34 歳 35～39 歳 40～44 歳 45～49 歳 50～54 歳 55～59 歳 60～64 歳 65～69 歳
# 0     158     127     161     181     278     206     213     181     143  \
# 1     680     653     766     890    1102     961     942     814     890
# 2    3278    3186    3720    4420    5268    4714    4012    3589    3750
# 3    7035    7416    8947   10536   12996   11391    9375    8330    9234
# 4  311470  329858  372869  423399  507856  447662  382032  342781  387685
#
#   70～74 歳  75 歳以上
# 0     157     269
# 1     966    1822
# 2    4350    8786
# 3   11050   21491
# 4  452539  859767

# %%
# Out:
# '千葉市稲毛区'

# %% [markdown]
# > まとめ
